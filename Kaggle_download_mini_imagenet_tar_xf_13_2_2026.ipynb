# %% [markdown]
# <a href="https://colab.research.google.com/github/Twenkid/Colab-Notebooks-AI-ML-CV/blob/main/Kaggle_download_mini_imagenet_tar_xf_13_2_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zcyzhchyu/mini-imagenet")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.86G/2.86G [00:32<00:00, 94.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet/versions/2

# %%
ls /.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet/versions/2
# Out:
# ls: cannot access '/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet/versions/2': No such file or directory

# %%
find .
# Out:
#   File "/tmp/ipython-input-1297992990.py", line 1
#     find .
#            ^
# SyntaxError: invalid syntax

# %%
# !find / | grep images.tar
# Out:
# /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet/versions/2/images.tar
# ^C

# %%
# !cd /content/ && tar -xf /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet/versions/2/images.tar

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !tar --help
# Out:
# Usage: tar [OPTION...] [FILE]...
# GNU 'tar' saves many files together into a single tape or disk archive, and can
# restore individual files from the archive.
#
# Examples:
#   tar -cf archive.tar foo bar  # Create archive.tar from files foo and bar.
#   tar -tvf archive.tar         # List all files in archive.tar verbosely.
#   tar -xf archive.tar          # Extract all files from archive.tar.
#
#  Main operation mode:
#   -A, --catenate, --concatenate   append tar files to an archive
#   -c, --create               create a new archive
#       --delete               delete from the archive (not on mag tapes!)
#   -d, --diff, --compare      find differences between archive and file system
#   -r, --append               append files to the end of an archive
#       --test-label           test the archive volume label and exit
#   -t, --list                 list the contents of an archive
#   -u, --update               only append files newer than copy in archive
# ...

# %%
# !tar /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet/versions/2/images.tar /content/
# Out:
# tar: Old option 'g' requires an argument.
# Try 'tar --help' or 'tar --usage' for more information.

# %%
# !ls /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet
# Out:
# 2.complete  versions

# %%
# !cd /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet/versions/

# %%
# !ls
# Out:
# sample_data

# %%
# !cd sample_data

# %%
# !ls
# Out:
# sample_data

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
# !cd /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet/versions/

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !pwd
# Out:
# /content/sample_data

# %%
cd /root/.cache/kagglehub
# Out:
# /root/.cache/kagglehub

# %%
# !pwd
# Out:
# /root/.cache/kagglehub

# %%
cd datasets/zcyzhcyu
# Out:
# [Errno 2] No such file or directory: 'datasets/zcyzhcyu'
# /root/.cache/kagglehub

# %%
# !ls
# Out:
# datasets

# %%
cd datasets
# Out:
# /root/.cache/kagglehub/datasets

# %%
# !ls
# Out:
# zcyzhchyu

# %%
# !cd zcyzhchyu/

# %%
# !ls
# Out:
# zcyzhchyu

# %%
# !cd zcyzhchyu/

# %%
# !ls
# Out:
# zcyzhchyu

# %%
ls zcy
# Out:
# ls: cannot access 'zcy': No such file or directory

# %%
# !ls zcyzhchyu/
# Out:
# mini-imagenet

# %%
# !cd mini-imagenet
# Out:
# /bin/bash: line 1: cd: mini-imagenet: No such file or directory

# %%
du .
# Out:
#   File "/tmp/ipython-input-3722915618.py", line 1
#     du .
#         ^
# SyntaxError: invalid syntax

# %%
du -h .
# Out:
#   File "/tmp/ipython-input-3098863125.py", line 1
#     du -h .
#            ^
# SyntaxError: invalid syntax

# %%
# !du -h .
# Out:
# 3.0G	./zcyzhchyu/mini-imagenet/versions/2
# 3.0G	./zcyzhchyu/mini-imagenet/versions
# 3.0G	./zcyzhchyu/mini-imagenet
# 3.0G	./zcyzhchyu
# 3.0G	.

# %%
cd ./zcyzhchyu/mini-imagenet/
# Out:
# /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet

# %%
# !ls
# Out:
# 2.complete  versions

# %%
cd 2.complete
# Out:
# [Errno 20] Not a directory: '2.complete'
# /root/.cache/kagglehub/datasets/zcyzhchyu/mini-imagenet

# %%
# !cd versions/

# %%
# !ls
# Out:
# 2.complete  versions

# %%
# !tar
